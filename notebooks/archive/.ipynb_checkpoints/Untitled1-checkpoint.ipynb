# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fpath = "/nfs/turbo/umms-indikar/shared/projects/evanData/1b_cluster_contours_rpi2_df.pkl"
df = pd.read_pickle(fpath)
df.head()
# Out:
#                                                    images_1
# 2020-12-01 00:00:01  000-0_hive4_rpi2_201201-000001-utc.jpg  \
# 2020-12-01 00:10:01  001-0_hive4_rpi2_201201-001001-utc.jpg
# 2020-12-01 00:20:01  002-0_hive4_rpi2_201201-002001-utc.jpg
# 2020-12-01 00:30:01  003-0_hive4_rpi2_201201-003001-utc.jpg
# 2020-12-01 00:40:01  004-0_hive4_rpi2_201201-004001-utc.jpg
#
#                                                    images_2
# 2020-12-01 00:00:01  000-1_hive4_rpi2_201201-000005-utc.jpg  \
# 2020-12-01 00:10:01  001-1_hive4_rpi2_201201-001005-utc.jpg
# 2020-12-01 00:20:01  002-1_hive4_rpi2_201201-002005-utc.jpg
# 2020-12-01 00:30:01  003-1_hive4_rpi2_201201-003005-utc.jpg
# 2020-12-01 00:40:01  004-1_hive4_rpi2_201201-004005-utc.jpg
#
#                                                        cluster_contour
# 2020-12-01 00:00:01  ([356, 357, 1625, 1626, 1626, 1625, 1625, 1624...  \
# 2020-12-01 00:10:01  ([355, 356, 1624, 1625, 1625, 1624, 1624, 1623...
# ...

# %%
df[['cluster_contour','cluster_center_mm', ]].head()
# Out:
#                                                        cluster_contour
# 2020-12-01 00:00:01  ([356, 357, 1625, 1626, 1626, 1625, 1625, 1624...  \
# 2020-12-01 00:10:01  ([355, 356, 1624, 1625, 1625, 1624, 1624, 1623...
# 2020-12-01 00:20:01  ([354, 355, 1627, 1628, 1628, 1627, 1627, 1628...
# 2020-12-01 00:30:01  ([352, 353, 1644, 1645, 1645, 1646, 1646, 1647...
# 2020-12-01 00:40:01  ([352, 353, 1646, 1647, 1647, 1648, 1648, 1656...
#
#                                   cluster_center_mm
# 2020-12-01 00:00:01   ([201.8, 0.49], [143.1, 0.8])
# 2020-12-01 00:10:01   ([199.7, 0.49], [144.7, 0.8])
# 2020-12-01 00:20:01  ([200.9, 0.49], [145.1, 0.81])
# 2020-12-01 00:30:01   ([197.5, 0.48], [144.9, 0.8])
# 2020-12-01 00:40:01  ([195.8, 0.48], [145.3, 0.81])

# %%
df2 = df[['cluster_contour','cluster_center_mm']]

outpath = "./test.csv"
df2.to_csv(outpath, index=True)

# %%
for idx, row in df.head(100).iterrows():
    cont = row['cluster_contour']
    # print(cont[0].shape)
    # print(cont[1].shape)

    plt.plot(cont[0], cont[1])
# Out:
# (1696,)
# (1696,)
# (1571,)
# (1571,)
# (1607,)
# (1607,)
# (1672,)
# (1672,)
# (1717,)
# (1717,)
# (1796,)
# (1796,)
# (1812,)
# (1812,)
# (1835,)
# (1835,)
# (1867,)
# (1867,)
# (1847,)
# (1847,)
# (1861,)
# (1861,)
# (1803,)
# (1803,)
# (1559,)
# (1559,)
# (1547,)
# (1547,)
# (1549,)
# (1549,)
# (1679,)
# (1679,)
# (1725,)
# (1725,)
# (1560,)
# (1560,)
# (1615,)
# (1615,)
# (1721,)
# (1721,)
# (1628,)
# (1628,)
# (1700,)
# (1700,)
# (1816,)
# (1816,)
# (1611,)
# (1611,)
# (1565,)
# (1565,)
# (1514,)
# (1514,)
# (1691,)
# (1691,)
# (1553,)
# (1553,)
# (1741,)
# (1741,)
# (1560,)
# (1560,)
# (1690,)
# (1690,)
# (1575,)
# (1575,)
# (1671,)
# (1671,)
# (1677,)
# (1677,)
# (1729,)
# (1729,)
# (1711,)
# (1711,)
# (1713,)
# (1713,)
# (1666,)
# (1666,)
# (1629,)
# (1629,)
# (1774,)
# (1774,)
# (1674,)
# (1674,)
# (1681,)
# (1681,)
# (1643,)
# (1643,)
# (1664,)
# (1664,)
# (1643,)
# (1643,)
# (1673,)
# (1673,)
# (1733,)
# (1733,)
# (1723,)
# (1723,)
# (1726,)
# (1726,)
# (1758,)
# (1758,)
# ...
