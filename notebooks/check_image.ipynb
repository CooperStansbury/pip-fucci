# %%
import matplotlib
import matplotlib.pyplot as plt
from tifffile import imread

# %%
rawPath = "/scratch/indikar_root/indikar1/cstansbu/woundHealing/images/C4.raw.tiff"

raw = imread(rawPath)
print(f"{raw.shape=}")

time = 15
channel = 1
img = raw[channel, time, :, :, :]

plt.rcParams['figure.dpi'] = 300
plt.imshow(img)
# Out:
# TiffFrame 291: missing required tags
# OME series: expected 291 frames, got 292
# raw.shape=(3, 97, 1747, 2410, 3)

# %%
rawPath = "/scratch/indikar_root/indikar1/cstansbu/woundHealing/images/C4.processed.tiff"

raw = imread(rawPath)
print(f"{raw.shape=}")

time = 15
channel = 1
img = raw[channel, time, :, :]

plt.rcParams['figure.dpi'] = 300
plt.imshow(img)
# Out:
# raw.shape=(3, 97, 874, 1205)
